# %%
import pickle
import pandas as pd
from IPython.display import display, Markdown, Latex

# %%
file_path = "D:\AA_develop\parse_docling\parsed_docs\parsed_FWG.pkl"
unpickled_df = pd.read_pickle(file_path)  
unpickled_df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\jongb\AppData\Local\Temp\ipykernel_12164\2366225327.py:1: SyntaxWarning: invalid escape sequence '\A'
#   file_path = "D:\AA_develop\parse_docling\parsed_docs\parsed_FWG.pkl"
# ...

# %%
for t in unpickled_df:
    # print(t.page_content)
    display(Markdown(t.page_content))
# Out:
# PLAN RECORD
#
# | REV. NO.   | DESCRIPTION                       | DRAWN BY   | DATE       | CHECKED   |
# |------------|-----------------------------------|------------|------------|-----------|
# | ORIG.      | ORIGINALLY PREPARED FOR 8250/8251 | J.S.YOON   | 2023.11.30 | S.H.HAN   |
# | 0          | ISSUED FOR PURCHASE ORDER.        | J.W.PARK   | 2023.12.18 | Y.U.KIM   |
#
# Prepared by Hyundai Heavy Industries Co., Ltd. on behalf of Hyundai Samho Heavy I ndustr ies Co., Ltd.
#
# 11
#
# 1
#
# 5
#
# 전장 협의
#
# SEC. NO. C2Y4
#
# DATE
#
# 2023. 11. 30.
#
# TEL. NO.
#
# SHIP NO.
#
# *1-6325
#
# 8250/8251
#
# APPROVED
#
# Hyunseung Kim
#
# CHECKED
#
# Seungho Han
#
# DRAWN
#
# Junsuk Yoon
#
# REFERENCE DRAWING NO.
#
# DRAWING SCALE
#
# HYUNDAI HEAVY INDUSTRIES CO., LTD. SAMHO SHIPYARD. KOREA
#
# 8250536-0
#
# SEQUENCE NO.
#
# ## CAUTION
#
# ...
